# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner


# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         713 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.1.0-py_1 conda-forge
#     branca:  0.4.0-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %%
import random # library for random number generation

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML

# %%
CLIENT_ID = "42O05QEKLZ0WFAN5BUSH2PKLNV332DA42M2BMOH3WDTJFLCG"
CLIENT_SECRET = "2RNCGC1D0SCKWKEMEOG2SMAAUMIVJX4NCKNOJU5IM1X1KMDW"
VERSION = '20180604'
LIMIT = 1000
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 42O05QEKLZ0WFAN5BUSH2PKLNV332DA42M2BMOH3WDTJFLCG
# CLIENT_SECRET:2RNCGC1D0SCKWKEMEOG2SMAAUMIVJX4NCKNOJU5IM1X1KMDW

# %%
address = '102 North End Ave, New York, NY'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7149555 -74.0153365

# %%
search_query = 'Chinese'
radius = 20000

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=42O05QEKLZ0WFAN5BUSH2PKLNV332DA42M2BMOH3WDTJFLCG&client_secret=2RNCGC1D0SCKWKEMEOG2SMAAUMIVJX4NCKNOJU5IM1X1KMDW&ll=40.7149555,-74.0153365&v=20180604&query=Chinese&radius=20000&limit=1000'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e988bb8ad1ab4001b0cee7b'},
#  'response': {'venues': [{'id': '4bf2dc586ba2b713560c8977',
#     'name': 'Chinese American IPA',
#     'location': {'address': '41 Elizabeth St',
#      'lat': 40.71972928254605,
#      'lng': -73.99996176189606,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71972928254605,
#        'lng': -73.99996176189606}],
#      'distance': 1401,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['41 Elizabeth St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4ebaede0a17c5dccac5210f7',
#     'name': 'Wall Street Chinese',
#     'location': {'address': '32 Broadway',
#      'lat': 40.705794,
#      'lng': -74.012721,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.705794,
#        'lng': -74.012721},
#       {'label': '?', 'lat': 40.705918, 'lng': -74.013026}],
#      'distance': 1043,
#      'postalCode': '10004',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['32 Broadway',
#       'New York, NY 10004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4bc0c78074a9a59359a7d0f6',
#     'name': 'Chinese-American Planning Council',
#     'location': {'address': '165 Eldridge St',
#      'crossStreet': 'at Delancey St.',
#      'lat': 40.719964153090444,
#      'lng': -73.99109818788692,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.719964153090444,
#        'lng': -73.99109818788692},
#       {'label': '?', 'lat': 40.72, 'lng': -73.99112}],
#      'distance': 2119,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['165 Eldridge St (at Delancey St.)',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4ce56fbd5bf68cfa65f23c17',
#     'name': 'Number One Chinese',
#     'location': {'address': '10 S William St',
#      'lat': 40.704573575379875,
#      'lng': -74.01040987598235,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.704573575379875,
#        'lng': -74.01040987598235},
#       {'label': '?', 'lat': 40.704726, 'lng': -74.010482}],
#      'distance': 1228,
#      'postalCode': '10004',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['10 S William St',
#       'New York, NY 10004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4c8fda03590ab1f7c76de27d',
#     'name': 'Chinese American Planning Council',
#     'location': {'address': '150 Elizabeth St',
#      'crossStreet': 'Kenmare St',
#      'lat': 40.72036386347542,
#      'lng': -73.99498828127511,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72036386347542,
#        'lng': -73.99498828127511}],
#      'distance': 1819,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['150 Elizabeth St (Kenmare St)',
#       'New York, NY 10012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4bf978b5bc869521a6b97a6b',
#     'name': 'OCM - Oversea Chinese Mission',
#     'location': {'address': '154 Hester St',
#      'crossStreet': 'at Elizabeth St.',
#      'lat': 40.717563959884664,
#      'lng': -73.99644379172986,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.717563959884664,
#        'lng': -73.99644379172986},
#       {'label': '?', 'lat': 40.71759, 'lng': -73.996545}],
#      'distance': 1620,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['154 Hester St (at Elizabeth St.)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4f3259a219836c91c7cf1778',
#     'name': 'Lei Ke Massage and Chinese Herbal Medicine',
#     'location': {'address': '265 Canal St',
#      'lat': 40.718838,
#      'lng': -74.000785,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.718838,
#        'lng': -74.000785}],
#      'distance': 1301,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['265 Canal St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '515f66e7e4b027e897d16e3c',
#     'name': 'Chinese Free Mason Athletic Association',
#     'location': {'lat': 40.71753591555177,
#      'lng': -73.99518388533123,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71753591555177,
#        'lng': -73.99518388533123}],
#      'distance': 1724,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '50328a8e91d4c4b30a586d6c',
#       'name': 'Non-Profit',
#       'pluralName': 'Non-Profits',
#       'shortName': 'Non-Profit',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4aaa8446f964a520465620e3',
#     'name': 'Chinese qi gong tui-na',
#     'location': {'address': '222 Lafayette St',
#      'crossStreet': 'Spring st',
#      'lat': 40.72206450971138,
#      'lng': -73.99675056632964,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72206450971138,
#        'lng': -73.99675056632964},
#       {'label': '?', 'lat': 40.722056, 'lng': -73.997518}],
#      'distance': 1756,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['222 Lafayette St (Spring st)',
#       'New York, NY 10012',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3c',
#       'name': 'Massage Studio',
#       'pluralName': 'Massage Studios',
#       'shortName': 'Massage Studio',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '51c87762498e29ad0293dab1',
#     'name': 'Chinese Mirch (WTC Truck)',
#     'location': {'lat': 40.713732,
#      'lng': -74.016616,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.713732,
#        'lng': -74.016616}],
#      'distance': 173,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4bac00a1f964a52025dd3ae3',
#     'name': 'Museum of Chinese in America (MOCA)',
#     'location': {'address': '215 Centre St',
#      'crossStreet': 'btwn Howard & Grand St',
#      'lat': 40.71936148321417,
#      'lng': -73.99908632040024,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71936148321417,
#        'lng': -73.99908632040024}],
#      'distance': 1456,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['215 Centre St (btwn Howard & Grand St)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d190941735',
#       'name': 'History Museum',
#       'pluralName': 'History Museums',
#       'shortName': 'History Museum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '58596016'},
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4fa89bb2e4b0bad89524b84a',
#     'name': 'Mission Chinese Food',
#     'location': {'address': '171 E Broadway',
#      'crossStreet': 'btwn Rutgers & Jefferson St',
#      'lat': 40.71408309640304,
#      'lng': -73.98978939638499,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71408309640304,
#        'lng': -73.98978939638499}],
#      'distance': 2157,
#      'postalCode': '10002',
#      'cc': 'US',
#      'neighborhood': 'Two Bridges',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['171 E Broadway (btwn Rutgers & Jefferson St)',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '455075',
#      'url': 'https://www.seamless.com/menu/mission-chinese-food-171-e-broadway-new-york/455075?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=455075',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '111402858'},
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '58aa398b14fb41097a0cf923',
#     'name': 'Great Fortune Chinese Restaurant 聚旺茶餐廳',
#     'location': {'address': '5 Catherine St',
#      'crossStreet': 'btwn E Broadway & Chatham Sq',
#      'lat': 40.713875,
#      'lng': -73.99728,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.713875,
#        'lng': -73.99728}],
#      'distance': 1528,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['5 Catherine St (btwn E Broadway & Chatham Sq)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '52af3a7c3cf9994f4e043bed',
#       'name': 'Cantonese Restaurant',
#       'pluralName': 'Cantonese Restaurants',
#       'shortName': 'Cantonese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4ed10e9db634dd2992446d6a',
#     'name': '123 Mott St Chinese Herbal Store',
#     'location': {'address': '123 Mott St',
#      'lat': 40.718171999999996,
#      'lng': -73.997114,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.718171999999996,
#        'lng': -73.997114},
#       {'label': '?', 'lat': 40.718123, 'lng': -73.997052}],
#      'distance': 1578,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['123 Mott St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4be582ab2457a5938e89ab15',
#     'name': 'Chinese Christian Herald Crusades - CCHC',
#     'location': {'address': '48 Allen St',
#      'crossStreet': 'Btw Grand and Hester',
#      'lat': 40.71653278145916,
#      'lng': -73.99183461476443,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71653278145916,
#        'lng': -73.99183461476443}],
#      'distance': 1990,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['48 Allen St (Btw Grand and Hester)',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d131941735',
#       'name': 'Spiritual Center',
#       'pluralName': 'Spiritual Centers',
#       'shortName': 'Spiritual',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4e4463cf52b18fcc799a9761',
#     'name': '88 Reach House chinese restaurant',
#     'location': {'address': '88 Division St',
#      'crossStreet': 'Eldrige street',
#      'lat': 40.714468,
#      'lng': -73.993727,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.714468,
#        'lng': -73.993727}],
#      'distance': 1824,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['88 Division St (Eldrige street)',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '50a94ef2e4b0f0766099e1e8',
#     'name': 'Chinese Kung-Fu Wu-Su Association',
#     'location': {'address': '28 W 27th St Fl 8',
#      'crossStreet': 'btwn Broadway & 6th Ave',
#      'lat': 40.74488185534032,
#      'lng': -73.98987767919222,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74488185534032,
#        'lng': -73.98987767919222}],
#      'distance': 3963,
#      'postalCode': '10001',
#      'cc': 'US',
#      'neighborhood': 'Chelsea',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['28 W 27th St Fl 8 (btwn Broadway & 6th Ave)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d101941735',
#       'name': 'Martial Arts Dojo',
#       'pluralName': 'Martial Arts Dojos',
#       'shortName': 'Martial Arts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_martialarts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '581299bb38fa2e54303f6891',
#     'name': 'Taste Chinese Restaurant',
#     'location': {'address': '178 Church St',
#      'lat': 40.7156902,
#      'lng': -74.0076053,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7156902,
#        'lng': -74.0076053}],
#      'distance': 657,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['178 Church St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '322507',
#      'url': 'https://www.seamless.com/menu/taste-chinese-restaurant-178-church-st-new-york/322507?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=322507',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4d02af0edc45a093ba95dfc6',
#     'name': 'New York Chinese Cultural Center',
#     'location': {'address': '440 Lafayette St',
#      'lat': 40.729357,
#      'lng': -73.992236,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.729357,
#        'lng': -73.992236},
#       {'label': '?', 'lat': 40.72944, 'lng': -73.992021}],
#      'distance': 2523,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['440 Lafayette St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a32',
#       'name': 'Cultural Center',
#       'pluralName': 'Cultural Centers',
#       'shortName': 'Cultural Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '582543c1b39f9613c18d8e2f',
#     'name': 'Chinese Tuxedo',
#     'location': {'address': '5 Doyers St',
#      'lat': 40.71443328935857,
#      'lng': -73.99798682863612,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71443328935857,
#        'lng': -73.99798682863612}],
#      'distance': 1465,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['5 Doyers St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '5176d244e4b08669e975294b',
#     'name': 'Chinese Opera Society',
#     'location': {'lat': 40.707793,
#      'lng': -74.011045,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.707793,
#        'lng': -74.011045}],
#      'distance': 875,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4aa6ec6af964a5207a4b20e3',
#     'name': 'Chinese Fast Wok',
#     'location': {'address': '230 7th Ave',
#      'crossStreet': 'btwn W 23rd & W 24th Sts.',
#      'lat': 40.744370788894514,
#      'lng': -73.99550313639813,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.744370788894514,
#        'lng': -73.99550313639813}],
#      'distance': 3677,
#      'postalCode': '10011',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['230 7th Ave (btwn W 23rd & W 24th Sts.)',
#       'New York, NY 10011',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1282927',
#      'url': 'https://www.seamless.com/menu/chinese-fast-wok-230-7th-ave-new-york/1282927?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1282927',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4e4cf8aabd413c4cc66da5a8',
#     'name': 'No. 1 Peking Chinese Restaurant',
#     'location': {'address': '746 Montgomery St',
#      'lat': 40.72646161066186,
#      'lng': -74.06758209803898,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72646161066186,
#        'lng': -74.06758209803898}],
#      'distance': 4590,
#      'postalCode': '07306',
#      'cc': 'US',
#      'city': 'Jersey City',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['746 Montgomery St',
#       'Jersey City, NJ 07306',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4c5c7cdf9b28d13a5ef25670',
#     'name': 'Chinese Qigong Tui-Na',
#     'location': {'address': '68 White St',
#      'crossStreet': 'Broadway',
#      'lat': 40.71838974952698,
#      'lng': -74.00427639484406,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71838974952698,
#        'lng': -74.00427639484406}],
#      'distance': 1008,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['68 White St (Broadway)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '51be2d6f498e7a73436bd59a',
#     'name': 'Chinese Qigong Massage',
#     'location': {'address': '68 White St',
#      'crossStreet': 'Broadway And Church',
#      'lat': 40.71819286828967,
#      'lng': -74.00281631295911,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71819286828967,
#        'lng': -74.00281631295911}],
#      'distance': 1116,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['68 White St (Broadway And Church)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3c',
#       'name': 'Massage Studio',
#       'pluralName': 'Massage Studios',
#       'shortName': 'Massage Studio',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '591d9063eacf4550665e3f18',
#     'name': 'Jiangnan Chinese Cuisine',
#     'location': {'address': '103 Washington St',
#      'lat': 40.70836717884017,
#      'lng': -74.01422925931902,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70836717884017,
#        'lng': -74.01422925931902}],
#      'distance': 739,
#      'postalCode': '10006',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['103 Washington St',
#       'New York, NY 10006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '437492343'},
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4bce036cb6c49c7409639691',
#     'name': 'Chinese East',
#     'location': {'lat': 40.74742877066695,
#      'lng': -73.99391561038274,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74742877066695,
#        'lng': -73.99391561038274}],
#      'distance': 4041,
#      'cc': 'US',
#      'state': 'New York',
#      'country': 'United States',
#      'formattedAddress': ['New York', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4102f800f964a5206a0b1fe3',
#     'name': 'Number One Chinese',
#     'location': {'address': '240 E 4th St',
#      'crossStreet': 'btw 3rd & 4th',
#      'lat': 40.72427999449375,
#      'lng': -73.9825753676373,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72427999449375,
#        'lng': -73.9825753676373}],
#      'distance': 2952,
#      'postalCode': '10009',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['240 E 4th St (btw 3rd & 4th)',
#       'New York, NY 10009',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4e7ccc711495736c91bccec6',
#     'name': 'Best Chinese Qi Gong Tui-Na',
#     'location': {'address': '316 W 14th St',
#      'crossStreet': '8th Ave',
#      'lat': 40.739936,
#      'lng': -74.003575,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.739936,
#        'lng': -74.003575}],
#      'distance': 2952,
#      'postalCode': '10014',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['316 W 14th St (8th Ave)',
#       'New York, NY 10014',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3c',
#       'name': 'Massage Studio',
#       'pluralName': 'Massage Studios',
#       'shortName': 'Massage Studio',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '52d5df8411d2e8ed825c31e1',
#     'name': 'Chinese Supermarket of Manhattan 新中華超市',
#     'location': {'address': '109 E Broadway',
#      'lat': 40.71353654129934,
#      'lng': -73.99308347972743,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71353654129934,
#        'lng': -73.99308347972743},
#       {'label': '?', 'lat': 40.713705, 'lng': -73.992916}],
#      'distance': 1884,
#      'postalCode': '10002',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['109 E Broadway',
#       'New York, NY 10002',
#       'United States']},
#     'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#       'name': 'Market',
#       'pluralName': 'Markets',
#       'shortName': 'Market',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '5d373d1fc46dcb00082ef5fc',
#     'name': 'NY Chinese Learning Center',
#     'location': {'address': '115 Broadway Street',
#      'lat': 40.70889,
#      'lng': -74.01145,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70889,
#        'lng': -74.01145}],
#      'distance': 750,
#      'postalCode': '10006',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['115 Broadway Street',
#       'New York, NY 10006',
#       'United States']},
#     'categories': [{'id': '56aa371ce4b08b9a8d573570',
#       'name': 'Adult Education Center',
#       'pluralName': 'Adult Education Centers',
#       'shortName': 'Adult Education Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4a986455f964a520c42b20e3',
#     'name': 'Precious Chinese Cuisine',
#     'location': {'address': '128 Washington St #1',
#      'crossStreet': 'btwn 1st St. & 2nd St.',
#      'lat': 40.7384499773291,
#      'lng': -74.03059677211883,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7384499773291,
#        'lng': -74.03059677211883}],
#      'distance': 2915,
#      'postalCode': '07030',
#      'cc': 'US',
#      'city': 'Hoboken',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['128 Washington St #1 (btwn 1st St. & 2nd St.)',
#       'Hoboken, NJ 07030',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '81210100'},
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '55f348b7498e60a6896b0144',
#     'name': 'Wenger Chinese Restaurant',
#     'location': {'address': '103 Washington Street, 2/F',
#      'lat': 40.707145,
#      'lng': -74.013607,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.707145,
#        'lng': -74.013607}],
#      'distance': 881,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['103 Washington Street, 2/F',
#       'New York, NY',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4e4c4d15bd413c4cc668571b',
#     'name': 'Hong Kong Chinese Restaurant',
#     'location': {'address': '174 Lexington Ave',
#      'lat': 40.73907788835601,
#      'lng': -73.99411073015166,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.73907788835601,
#        'lng': -73.99411073015166}],
#      'distance': 3227,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['174 Lexington Ave',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '501995eee4b02d5a4aca4945',
#     'name': '"Charming Beijing" Chinese Painting Exhibition',
#     'location': {'address': '40 Broad St',
#      'lat': 40.7061109542847,
#      'lng': -74.0115966796875,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7061109542847,
#        'lng': -74.0115966796875}],
#      'distance': 1033,
#      'postalCode': '10004',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['40 Broad St',
#       'New York, NY 10004',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4f3290ad19836c91c7e431ae',
#     'name': 'P and C Garden Chinese Restaurant',
#     'location': {'address': '44 Trinity Pl',
#      'lat': 40.707068,
#      'lng': -74.013501,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.707068,
#        'lng': -74.013501}],
#      'distance': 891,
#      'postalCode': '10006',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['44 Trinity Pl',
#       'New York, NY 10006',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4d9f724e49afb60c583e9e8d',
#     'name': 'Chinese Mission To The UN',
#     'location': {'address': '845 United Nations Plz',
#      'lat': 40.744832387540995,
#      'lng': -73.9737175658148,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.744832387540995,
#        'lng': -73.9737175658148}],
#      'distance': 4836,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['845 United Nations Plz',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d126941735',
#       'name': 'Government Building',
#       'pluralName': 'Government Buildings',
#       'shortName': 'Government',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4d84f99602eb548100393af5',
#     'name': 'New York Chinese Shaolin Center',
#     'location': {'address': '39 E 20th St Fl 4',
#      'lat': 40.73888654096456,
#      'lng': -73.98870469135245,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.73888654096456,
#        'lng': -73.98870469135245}],
#      'distance': 3484,
#      'postalCode': '10003',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['39 E 20th St Fl 4',
#       'New York, NY 10003',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d101941735',
#       'name': 'Martial Arts Dojo',
#       'pluralName': 'Martial Arts Dojos',
#       'shortName': 'Martial Arts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_martialarts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '518d1568498e1fbf0aa42044',
#     'name': 'First Chinese Presbyterian Community Affairs Home Attendant Corporation',
#     'location': {'address': '30 Broad St',
#      'lat': 40.70607620131042,
#      'lng': -74.01120589355607,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70607620131042,
#        'lng': -74.01120589355607}],
#      'distance': 1048,
#      'postalCode': '10004',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['30 Broad St',
#       'New York, NY 10004',
#       'United States']},
#     'categories': [{'id': '50328a8e91d4c4b30a586d6c',
#       'name': 'Non-Profit',
#       'pluralName': 'Non-Profits',
#       'shortName': 'Non-Profit',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4ade8943f964a5204b7621e3',
#     'name': 'Chinese Musician Restaurant',
#     'location': {'address': '151 Greenpoint Ave',
#      'crossStreet': 'Manhattan Ave.',
#      'lat': 40.730255959180006,
#      'lng': -73.95377261718139,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.730255959180006,
#        'lng': -73.95377261718139},
#       {'label': '?', 'lat': 40.73033, 'lng': -73.953733}],
#      'distance': 5466,
#      'postalCode': '11222',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['151 Greenpoint Ave (Manhattan Ave.)',
#       'Brooklyn, NY 11222',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4c2e42d5987f20a1c4de4aaa',
#     'name': 'Kam Feng Chinese Food',
#     'location': {'address': '121 Smith St',
#      'crossStreet': 'btwn Dean & Pacific St',
#      'lat': 40.687613,
#      'lng': -73.98960699999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.687613,
#        'lng': -73.98960699999999},
#       {'label': '?', 'lat': 40.687655, 'lng': -73.989713}],
#      'distance': 3738,
#      'postalCode': '11201',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['121 Smith St (btwn Dean & Pacific St)',
#       'Brooklyn, NY 11201',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4cedb76028abb60c2dc5b909',
#     'name': 'No. 1 Fine Chinese Cuisine',
#     'location': {'address': '642 Washington St',
#      'lat': 40.744560669636286,
#      'lng': -74.02871844906825,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.744560669636286,
#        'lng': -74.02871844906825},
#       {'label': '?', 'lat': 40.744609, 'lng': -74.028908}],
#      'distance': 3483,
#      'postalCode': '07030',
#      'cc': 'US',
#      'city': 'Hoboken',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['642 Washington St',
#       'Hoboken, NJ 07030',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4b6b58c6f964a52077022ce3',
#     'name': 'Taste Chinese Restaurant',
#     'location': {'address': '34 Lexington Ave',
#      'crossStreet': 'E 24th St',
#      'lat': 40.73999901280863,
#      'lng': -73.98454388899373,
#      'distance': 3810,
#      'postalCode': '10010',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['34 Lexington Ave (E 24th St)',
#       'New York, NY 10010',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4cc71982be40a35d07fb8d4c',
#     'name': 'Chinese Food Restaurant.',
#     'location': {'address': '1814 Bergenline Ave',
#      'lat': 40.773785292722096,
#      'lng': -74.03474869178378,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.773785292722096,
#        'lng': -74.03474869178378}],
#      'distance': 6750,
#      'postalCode': '07087',
#      'cc': 'US',
#      'city': 'Union City',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['1814 Bergenline Ave',
#       'Union City, NJ 07087',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4e47cf21183849317e88e276',
#     'name': 'New York Chinese Baptist Church',
#     'location': {'address': '82 Walker St',
#      'lat': 40.718378,
#      'lng': -74.00146600000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.718378,
#        'lng': -74.00146600000001},
#       {'label': '?', 'lat': 40.718266, 'lng': -74.001556}],
#      'distance': 1230,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['82 Walker St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '5012c0fde4b0748a78b0c886',
#     'name': "Ann's Chinese Restaurant",
#     'location': {'address': '1 E Broadway #2FL',
#      'lat': 40.71702941781792,
#      'lng': -74.00175467770325,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71702941781792,
#        'lng': -74.00175467770325}],
#      'distance': 1168,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1 E Broadway #2FL',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '58a4fb9d30ecc618cdd5c3e2',
#     'name': 'Pinch Chinese',
#     'location': {'address': '177 Prince St',
#      'lat': 40.726356519860495,
#      'lng': -74.00194814736723,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.726356519860495,
#        'lng': -74.00194814736723}],
#      'distance': 1699,
#      'postalCode': '10012',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['177 Prince St',
#       'New York, NY 10012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '504559',
#      'url': 'https://www.seamless.com/menu/pinch-chinese-177-prince-st-new-york/504559?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=504559',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '401297266'},
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4b0c24a8f964a520b43723e3',
#     'name': 'No. 1 Chinese Restauant',
#     'location': {'address': '705 Fulton St',
#      'crossStreet': 'St. Felix St',
#      'lat': 40.6874018497523,
#      'lng': -73.97731685983138,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.6874018497523,
#        'lng': -73.97731685983138},
#       {'label': '?', 'lat': 40.687557, 'lng': -73.977254}],
#      'distance': 4438,
#      'postalCode': '11217',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['705 Fulton St (St. Felix St)',
#       'Brooklyn, NY 11217',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '268037',
#      'url': 'https://www.seamless.com/menu/no-1-chinese-restaurant-705-fulton-st-brooklyn/268037?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=268037',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4f320f6d19833175d60c8d97',
#     'name': 'Downtown Chinese Restaurant',
#     'location': {'address': '135 John St',
#      'lat': 40.707125,
#      'lng': -74.005213,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.707125,
#        'lng': -74.005213},
#       {'label': '?', 'lat': 40.707098, 'lng': -74.005032}],
#      'distance': 1220,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['135 John St',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False},
#    {'id': '4d0d1b2c257d6dcbb5269a67',
#     'name': 'Park Ave Chinese',
#     'location': {'address': '169 Park Ave',
#      'crossStreet': 'Adelphi Street',
#      'lat': 40.696357,
#      'lng': -73.972734,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.696357,
#        'lng': -73.972734}],
#      'distance': 4148,
#      'postalCode': '11205',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['169 Park Ave (Adelphi Street)',
#       'Brooklyn, NY 11205',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587055622',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...         NaN
# 1  [{'id': '4bf58dd8d48988d1f1931735', 'name': 'G...         NaN
# 2  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...         NaN
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...         NaN
# 4  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...         NaN
#
#   delivery.provider.icon.name delivery.provider.icon.prefix  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.name delivery.url  hasPerk  \
# 0                          NaN                    NaN          NaN    False
# 1                          NaN                    NaN          NaN    False
# 2                          NaN                    NaN          NaN    False
# 3                          NaN                    NaN          NaN    False
# 4                          NaN                    NaN          NaN    False
#
#                          id  location.address  ...  \
# 0  4bf2dc586ba2b713560c8977   41 Elizabeth St  ...
# 1  4ebaede0a17c5dccac5210f7       32 Broadway  ...
# 2  4bc0c78074a9a59359a7d0f6   165 Eldridge St  ...
# 3  4ce56fbd5bf68cfa65f23c17   10 S William St  ...
# 4  4c8fda03590ab1f7c76de27d  150 Elizabeth St  ...
#
#                            location.formattedAddress  \
# 0  [41 Elizabeth St, New York, NY 10013, United S...
# 1   [32 Broadway, New York, NY 10004, United States]
# 2  [165 Eldridge St (at Delancey St.), New York, ...
# 3  [10 S William St, New York, NY 10004, United S...
# 4  [150 Elizabeth St (Kenmare St), New York, NY 1...
#
#                              location.labeledLatLngs location.lat  \
# 0  [{'label': 'display', 'lat': 40.71972928254605...    40.719729
# 1  [{'label': 'display', 'lat': 40.705794, 'lng':...    40.705794
# 2  [{'label': 'display', 'lat': 40.71996415309044...    40.719964
# 3  [{'label': 'display', 'lat': 40.70457357537987...    40.704574
# 4  [{'label': 'display', 'lat': 40.72036386347542...    40.720364
#
#   location.lng  location.neighborhood location.postalCode location.state  \
# 0   -73.999962                    NaN               10013             NY
# 1   -74.012721                    NaN               10004             NY
# 2   -73.991098                    NaN               10002             NY
# 3   -74.010410                    NaN               10004             NY
# 4   -73.994988                    NaN               10012             NY
#
#                                 name    referralId venuePage.id
# 0               Chinese American IPA  v-1587055622          NaN
# 1                Wall Street Chinese  v-1587055622          NaN
# 2  Chinese-American Planning Council  v-1587055622          NaN
# 3                 Number One Chinese  v-1587055622          NaN
# 4  Chinese American Planning Council  v-1587055622          NaN
#
# [5 rows x 25 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name              categories  \
# 0                                Chinese American IPA                  Office
# 1                                 Wall Street Chinese   General Entertainment
# 2                   Chinese-American Planning Council                  Office
# 3                                  Number One Chinese      Chinese Restaurant
# 4                   Chinese American Planning Council                  Office
# 5                       OCM - Oversea Chinese Mission                  Church
# 6          Lei Ke Massage and Chinese Herbal Medicine                    Food
# 7             Chinese Free Mason Athletic Association              Non-Profit
# 8                              Chinese qi gong tui-na          Massage Studio
# 9                           Chinese Mirch (WTC Truck)              Food Truck
# 10                Museum of Chinese in America (MOCA)          History Museum
# 11                               Mission Chinese Food      Chinese Restaurant
# 12             Great Fortune Chinese Restaurant 聚旺茶餐廳    Cantonese Restaurant
# 13                   123 Mott St Chinese Herbal Store                Pharmacy
# 14           Chinese Christian Herald Crusades - CCHC        Spiritual Center
# 15                  88 Reach House chinese restaurant      Chinese Restaurant
# 16                  Chinese Kung-Fu Wu-Su Association       Martial Arts Dojo
# 17                           Taste Chinese Restaurant      Chinese Restaurant
# 18                   New York Chinese Cultural Center         Cultural Center
# 19                                     Chinese Tuxedo      Chinese Restaurant
# 20                              Chinese Opera Society   General Entertainment
# 21                                   Chinese Fast Wok      Chinese Restaurant
# 22                    No. 1 Peking Chinese Restaurant      Chinese Restaurant
# 23                              Chinese Qigong Tui-Na                    None
# 24                             Chinese Qigong Massage          Massage Studio
# 25                           Jiangnan Chinese Cuisine      Chinese Restaurant
# 26                                       Chinese East      Chinese Restaurant
# 27                                 Number One Chinese      Chinese Restaurant
# 28                        Best Chinese Qi Gong Tui-Na          Massage Studio
# 29             Chinese Supermarket of Manhattan 新中華超市                  Market
# 30                         NY Chinese Learning Center  Adult Education Center
# 31                           Precious Chinese Cuisine      Chinese Restaurant
# 32                          Wenger Chinese Restaurant      Chinese Restaurant
# 33                       Hong Kong Chinese Restaurant      Chinese Restaurant
# 34     "Charming Beijing" Chinese Painting Exhibition                    None
# 35                  P and C Garden Chinese Restaurant                    Food
# 36                          Chinese Mission To The UN     Government Building
# 37                    New York Chinese Shaolin Center       Martial Arts Dojo
# 38  First Chinese Presbyterian Community Affairs H...              Non-Profit
# 39                        Chinese Musician Restaurant      Chinese Restaurant
# 40                              Kam Feng Chinese Food      Chinese Restaurant
# 41                         No. 1 Fine Chinese Cuisine        Asian Restaurant
# 42                           Taste Chinese Restaurant      Chinese Restaurant
# 43                           Chinese Food Restaurant.                    None
# 44                    New York Chinese Baptist Church                  Church
# 45                           Ann's Chinese Restaurant        Asian Restaurant
# 46                                      Pinch Chinese      Chinese Restaurant
# 47                            No. 1 Chinese Restauant      Chinese Restaurant
# 48                        Downtown Chinese Restaurant                    Food
# 49                                   Park Ave Chinese      Chinese Restaurant
#
#                        address  cc         city        country  \
# 0              41 Elizabeth St  US     New York  United States
# 1                  32 Broadway  US     New York  United States
# 2              165 Eldridge St  US     New York  United States
# 3              10 S William St  US     New York  United States
# 4             150 Elizabeth St  US     New York  United States
# 5                154 Hester St  US     New York  United States
# 6                 265 Canal St  US     New York  United States
# 7                          NaN  US     New York  United States
# 8             222 Lafayette St  US     New York  United States
# 9                          NaN  US     New York  United States
# 10               215 Centre St  US     New York  United States
# 11              171 E Broadway  US     New York  United States
# 12              5 Catherine St  US     New York  United States
# 13                 123 Mott St  US     New York  United States
# 14                 48 Allen St  US     New York  United States
# 15              88 Division St  US     New York  United States
# 16           28 W 27th St Fl 8  US     New York  United States
# 17               178 Church St  US     New York  United States
# 18            440 Lafayette St  US     New York  United States
# 19                 5 Doyers St  US     New York  United States
# 20                         NaN  US     New York  United States
# 21                 230 7th Ave  US     New York  United States
# 22           746 Montgomery St  US  Jersey City  United States
# 23                 68 White St  US     New York  United States
# 24                 68 White St  US     New York  United States
# 25           103 Washington St  US     New York  United States
# 26                         NaN  US          NaN  United States
# 27                240 E 4th St  US     New York  United States
# 28               316 W 14th St  US     New York  United States
# 29              109 E Broadway  US     New York  United States
# 30         115 Broadway Street  US     New York  United States
# 31        128 Washington St #1  US      Hoboken  United States
# 32  103 Washington Street, 2/F  US     New York  United States
# 33           174 Lexington Ave  US     New York  United States
# 34                 40 Broad St  US     New York  United States
# 35               44 Trinity Pl  US     New York  United States
# 36      845 United Nations Plz  US     New York  United States
# 37           39 E 20th St Fl 4  US     New York  United States
# 38                 30 Broad St  US     New York  United States
# 39          151 Greenpoint Ave  US     Brooklyn  United States
# 40                121 Smith St  US     Brooklyn  United States
# 41           642 Washington St  US      Hoboken  United States
# 42            34 Lexington Ave  US     New York  United States
# 43         1814 Bergenline Ave  US   Union City  United States
# 44                82 Walker St  US     New York  United States
# 45           1 E Broadway #2FL  US     New York  United States
# 46               177 Prince St  US     New York  United States
# 47               705 Fulton St  US     Brooklyn  United States
# 48                 135 John St  US     New York  United States
# 49                169 Park Ave  US     Brooklyn  United States
#
#                      crossStreet  distance  \
# 0                            NaN      1401
# 1                            NaN      1043
# 2                at Delancey St.      2119
# 3                            NaN      1228
# 4                     Kenmare St      1819
# 5               at Elizabeth St.      1620
# 6                            NaN      1301
# 7                            NaN      1724
# 8                      Spring st      1756
# 9                            NaN       173
# 10        btwn Howard & Grand St      1456
# 11   btwn Rutgers & Jefferson St      2157
# 12  btwn E Broadway & Chatham Sq      1528
# 13                           NaN      1578
# 14          Btw Grand and Hester      1990
# 15                Eldrige street      1824
# 16       btwn Broadway & 6th Ave      3963
# 17                           NaN       657
# 18                           NaN      2523
# 19                           NaN      1465
# 20                           NaN       875
# 21     btwn W 23rd & W 24th Sts.      3677
# 22                           NaN      4590
# 23                      Broadway      1008
# 24           Broadway And Church      1116
# 25                           NaN       739
# 26                           NaN      4041
# 27                 btw 3rd & 4th      2952
# 28                       8th Ave      2952
# 29                           NaN      1884
# 30                           NaN       750
# 31        btwn 1st St. & 2nd St.      2915
# 32                           NaN       881
# 33                           NaN      3227
# 34                           NaN      1033
# 35                           NaN       891
# 36                           NaN      4836
# 37                           NaN      3484
# 38                           NaN      1048
# 39                Manhattan Ave.      5466
# 40        btwn Dean & Pacific St      3738
# 41                           NaN      3483
# 42                     E 24th St      3810
# 43                           NaN      6750
# 44                           NaN      1230
# 45                           NaN      1168
# 46                           NaN      1699
# 47                  St. Felix St      4438
# 48                           NaN      1220
# 49                Adelphi Street      4148
#
#                                      formattedAddress  \
# 0   [41 Elizabeth St, New York, NY 10013, United S...
# 1    [32 Broadway, New York, NY 10004, United States]
# 2   [165 Eldridge St (at Delancey St.), New York, ...
# 3   [10 S William St, New York, NY 10004, United S...
# 4   [150 Elizabeth St (Kenmare St), New York, NY 1...
# 5   [154 Hester St (at Elizabeth St.), New York, N...
# 6   [265 Canal St, New York, NY 10013, United States]
# 7                       [New York, NY, United States]
# 8   [222 Lafayette St (Spring st), New York, NY 10...
# 9                       [New York, NY, United States]
# 10  [215 Centre St (btwn Howard & Grand St), New Y...
# 11  [171 E Broadway (btwn Rutgers & Jefferson St),...
# 12  [5 Catherine St (btwn E Broadway & Chatham Sq)...
# 13   [123 Mott St, New York, NY 10013, United States]
# 14  [48 Allen St (Btw Grand and Hester), New York,...
# 15  [88 Division St (Eldrige street), New York, NY...
# 16  [28 W 27th St Fl 8 (btwn Broadway & 6th Ave), ...
# 17  [178 Church St, New York, NY 10013, United Sta...
# 18  [440 Lafayette St, New York, NY 10013, United ...
# 19   [5 Doyers St, New York, NY 10013, United States]
# 20                      [New York, NY, United States]
# 21  [230 7th Ave (btwn W 23rd & W 24th Sts.), New ...
# 22  [746 Montgomery St, Jersey City, NJ 07306, Uni...
# 23  [68 White St (Broadway), New York, NY 10013, U...
# 24  [68 White St (Broadway And Church), New York, ...
# 25  [103 Washington St, New York, NY 10006, United...
# 26                          [New York, United States]
# 27  [240 E 4th St (btw 3rd & 4th), New York, NY 10...
# 28  [316 W 14th St (8th Ave), New York, NY 10014, ...
# 29  [109 E Broadway, New York, NY 10002, United St...
# 30  [115 Broadway Street, New York, NY 10006, Unit...
# 31  [128 Washington St #1 (btwn 1st St. & 2nd St.)...
# 32  [103 Washington Street, 2/F, New York, NY, Uni...
# 33  [174 Lexington Ave, New York, NY 10016, United...
# 34   [40 Broad St, New York, NY 10004, United States]
# 35  [44 Trinity Pl, New York, NY 10006, United Sta...
# 36  [845 United Nations Plz, New York, NY 10017, U...
# 37  [39 E 20th St Fl 4, New York, NY 10003, United...
# 38   [30 Broad St, New York, NY 10004, United States]
# 39  [151 Greenpoint Ave (Manhattan Ave.), Brooklyn...
# 40  [121 Smith St (btwn Dean & Pacific St), Brookl...
# 41  [642 Washington St, Hoboken, NJ 07030, United ...
# 42  [34 Lexington Ave (E 24th St), New York, NY 10...
# 43  [1814 Bergenline Ave, Union City, NJ 07087, Un...
# 44  [82 Walker St, New York, NY 10013, United States]
# 45  [1 E Broadway #2FL, New York, NY 10038, United...
# 46  [177 Prince St, New York, NY 10012, United Sta...
# 47  [705 Fulton St (St. Felix St), Brooklyn, NY 11...
# 48   [135 John St, New York, NY 10038, United States]
# 49  [169 Park Ave (Adelphi Street), Brooklyn, NY 1...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 40.71972928254605...  40.719729 -73.999962
# 1   [{'label': 'display', 'lat': 40.705794, 'lng':...  40.705794 -74.012721
# 2   [{'label': 'display', 'lat': 40.71996415309044...  40.719964 -73.991098
# 3   [{'label': 'display', 'lat': 40.70457357537987...  40.704574 -74.010410
# 4   [{'label': 'display', 'lat': 40.72036386347542...  40.720364 -73.994988
# 5   [{'label': 'display', 'lat': 40.71756395988466...  40.717564 -73.996444
# 6   [{'label': 'display', 'lat': 40.718838, 'lng':...  40.718838 -74.000785
# 7   [{'label': 'display', 'lat': 40.71753591555177...  40.717536 -73.995184
# 8   [{'label': 'display', 'lat': 40.72206450971138...  40.722065 -73.996751
# 9   [{'label': 'display', 'lat': 40.713732, 'lng':...  40.713732 -74.016616
# 10  [{'label': 'display', 'lat': 40.71936148321417...  40.719361 -73.999086
# 11  [{'label': 'display', 'lat': 40.71408309640304...  40.714083 -73.989789
# 12  [{'label': 'display', 'lat': 40.713875, 'lng':...  40.713875 -73.997280
# 13  [{'label': 'display', 'lat': 40.71817199999999...  40.718172 -73.997114
# 14  [{'label': 'display', 'lat': 40.71653278145916...  40.716533 -73.991835
# 15  [{'label': 'display', 'lat': 40.714468, 'lng':...  40.714468 -73.993727
# 16  [{'label': 'display', 'lat': 40.74488185534032...  40.744882 -73.989878
# 17  [{'label': 'display', 'lat': 40.7156902, 'lng'...  40.715690 -74.007605
# 18  [{'label': 'display', 'lat': 40.729357, 'lng':...  40.729357 -73.992236
# 19  [{'label': 'display', 'lat': 40.71443328935857...  40.714433 -73.997987
# 20  [{'label': 'display', 'lat': 40.707793, 'lng':...  40.707793 -74.011045
# 21  [{'label': 'display', 'lat': 40.74437078889451...  40.744371 -73.995503
# 22  [{'label': 'display', 'lat': 40.72646161066186...  40.726462 -74.067582
# 23  [{'label': 'display', 'lat': 40.71838974952698...  40.718390 -74.004276
# 24  [{'label': 'display', 'lat': 40.71819286828967...  40.718193 -74.002816
# 25  [{'label': 'display', 'lat': 40.70836717884017...  40.708367 -74.014229
# 26  [{'label': 'display', 'lat': 40.74742877066695...  40.747429 -73.993916
# 27  [{'label': 'display', 'lat': 40.72427999449375...  40.724280 -73.982575
# 28  [{'label': 'display', 'lat': 40.739936, 'lng':...  40.739936 -74.003575
# 29  [{'label': 'display', 'lat': 40.71353654129934...  40.713537 -73.993083
# 30  [{'label': 'display', 'lat': 40.70889, 'lng': ...  40.708890 -74.011450
# 31  [{'label': 'display', 'lat': 40.7384499773291,...  40.738450 -74.030597
# 32  [{'label': 'display', 'lat': 40.707145, 'lng':...  40.707145 -74.013607
# 33  [{'label': 'display', 'lat': 40.73907788835601...  40.739078 -73.994111
# 34  [{'label': 'display', 'lat': 40.7061109542847,...  40.706111 -74.011597
# 35  [{'label': 'display', 'lat': 40.707068, 'lng':...  40.707068 -74.013501
# 36  [{'label': 'display', 'lat': 40.74483238754099...  40.744832 -73.973718
# 37  [{'label': 'display', 'lat': 40.73888654096456...  40.738887 -73.988705
# 38  [{'label': 'display', 'lat': 40.70607620131042...  40.706076 -74.011206
# 39  [{'label': 'display', 'lat': 40.73025595918000...  40.730256 -73.953773
# 40  [{'label': 'display', 'lat': 40.687613, 'lng':...  40.687613 -73.989607
# 41  [{'label': 'display', 'lat': 40.74456066963628...  40.744561 -74.028718
# 42                                                NaN  40.739999 -73.984544
# 43  [{'label': 'display', 'lat': 40.77378529272209...  40.773785 -74.034749
# 44  [{'label': 'display', 'lat': 40.718378, 'lng':...  40.718378 -74.001466
# 45  [{'label': 'display', 'lat': 40.71702941781792...  40.717029 -74.001755
# 46  [{'label': 'display', 'lat': 40.72635651986049...  40.726357 -74.001948
# 47  [{'label': 'display', 'lat': 40.6874018497523,...  40.687402 -73.977317
# 48  [{'label': 'display', 'lat': 40.707125, 'lng':...  40.707125 -74.005213
# 49  [{'label': 'display', 'lat': 40.696357, 'lng':...  40.696357 -73.972734
#
#    neighborhood postalCode     state                        id
# 0           NaN      10013        NY  4bf2dc586ba2b713560c8977
# 1           NaN      10004        NY  4ebaede0a17c5dccac5210f7
# 2           NaN      10002        NY  4bc0c78074a9a59359a7d0f6
# 3           NaN      10004        NY  4ce56fbd5bf68cfa65f23c17
# 4           NaN      10012        NY  4c8fda03590ab1f7c76de27d
# 5           NaN      10013        NY  4bf978b5bc869521a6b97a6b
# 6           NaN      10013        NY  4f3259a219836c91c7cf1778
# 7           NaN        NaN        NY  515f66e7e4b027e897d16e3c
# 8           NaN      10012        NY  4aaa8446f964a520465620e3
# 9           NaN        NaN        NY  51c87762498e29ad0293dab1
# 10          NaN      10013        NY  4bac00a1f964a52025dd3ae3
# 11  Two Bridges      10002        NY  4fa89bb2e4b0bad89524b84a
# 12          NaN      10038        NY  58aa398b14fb41097a0cf923
# 13          NaN      10013        NY  4ed10e9db634dd2992446d6a
# 14          NaN      10002        NY  4be582ab2457a5938e89ab15
# 15          NaN      10002        NY  4e4463cf52b18fcc799a9761
# 16      Chelsea      10001        NY  50a94ef2e4b0f0766099e1e8
# 17          NaN      10013        NY  581299bb38fa2e54303f6891
# 18          NaN      10013        NY  4d02af0edc45a093ba95dfc6
# 19          NaN      10013        NY  582543c1b39f9613c18d8e2f
# 20          NaN        NaN        NY  5176d244e4b08669e975294b
# 21          NaN      10011        NY  4aa6ec6af964a5207a4b20e3
# 22          NaN      07306        NJ  4e4cf8aabd413c4cc66da5a8
# 23          NaN      10013        NY  4c5c7cdf9b28d13a5ef25670
# 24          NaN      10013        NY  51be2d6f498e7a73436bd59a
# 25          NaN      10006        NY  591d9063eacf4550665e3f18
# 26          NaN        NaN  New York  4bce036cb6c49c7409639691
# 27          NaN      10009        NY  4102f800f964a5206a0b1fe3
# 28          NaN      10014        NY  4e7ccc711495736c91bccec6
# 29          NaN      10002        NY  52d5df8411d2e8ed825c31e1
# 30          NaN      10006        NY  5d373d1fc46dcb00082ef5fc
# 31          NaN      07030        NJ  4a986455f964a520c42b20e3
# 32          NaN        NaN        NY  55f348b7498e60a6896b0144
# 33          NaN      10016        NY  4e4c4d15bd413c4cc668571b
# 34          NaN      10004        NY  501995eee4b02d5a4aca4945
# 35          NaN      10006        NY  4f3290ad19836c91c7e431ae
# 36          NaN      10017        NY  4d9f724e49afb60c583e9e8d
# 37          NaN      10003        NY  4d84f99602eb548100393af5
# 38          NaN      10004        NY  518d1568498e1fbf0aa42044
# 39          NaN      11222        NY  4ade8943f964a5204b7621e3
# 40          NaN      11201        NY  4c2e42d5987f20a1c4de4aaa
# 41          NaN      07030        NJ  4cedb76028abb60c2dc5b909
# 42          NaN      10010        NY  4b6b58c6f964a52077022ce3
# 43          NaN      07087        NJ  4cc71982be40a35d07fb8d4c
# 44          NaN      10013        NY  4e47cf21183849317e88e276
# 45          NaN      10038        NY  5012c0fde4b0748a78b0c886
# 46          NaN      10012        NY  58a4fb9d30ecc618cdd5c3e2
# 47          NaN      11217        NY  4b0c24a8f964a520b43723e3
# 48          NaN      10038        NY  4f320f6d19833175d60c8d97
# 49          NaN      11205        NY  4d0d1b2c257d6dcbb5269a67

# %%
dataframe_filtered.name
# Out:
# 0                                  Chinese American IPA
# 1                                   Wall Street Chinese
# 2                     Chinese-American Planning Council
# 3                                    Number One Chinese
# 4                     Chinese American Planning Council
# 5                         OCM - Oversea Chinese Mission
# 6            Lei Ke Massage and Chinese Herbal Medicine
# 7               Chinese Free Mason Athletic Association
# 8                                Chinese qi gong tui-na
# 9                             Chinese Mirch (WTC Truck)
# 10                  Museum of Chinese in America (MOCA)
# 11                                 Mission Chinese Food
# 12               Great Fortune Chinese Restaurant 聚旺茶餐廳
# 13                     123 Mott St Chinese Herbal Store
# 14             Chinese Christian Herald Crusades - CCHC
# 15                    88 Reach House chinese restaurant
# 16                    Chinese Kung-Fu Wu-Su Association
# 17                             Taste Chinese Restaurant
# 18                     New York Chinese Cultural Center
# 19                                       Chinese Tuxedo
# 20                                Chinese Opera Society
# 21                                     Chinese Fast Wok
# 22                      No. 1 Peking Chinese Restaurant
# 23                                Chinese Qigong Tui-Na
# 24                               Chinese Qigong Massage
# 25                             Jiangnan Chinese Cuisine
# 26                                         Chinese East
# 27                                   Number One Chinese
# 28                          Best Chinese Qi Gong Tui-Na
# 29               Chinese Supermarket of Manhattan 新中華超市
# 30                           NY Chinese Learning Center
# 31                             Precious Chinese Cuisine
# 32                            Wenger Chinese Restaurant
# 33                         Hong Kong Chinese Restaurant
# 34       "Charming Beijing" Chinese Painting Exhibition
# 35                    P and C Garden Chinese Restaurant
# 36                            Chinese Mission To The UN
# 37                      New York Chinese Shaolin Center
# 38    First Chinese Presbyterian Community Affairs H...
# 39                          Chinese Musician Restaurant
# 40                                Kam Feng Chinese Food
# 41                           No. 1 Fine Chinese Cuisine
# 42                             Taste Chinese Restaurant
# 43                             Chinese Food Restaurant.
# 44                      New York Chinese Baptist Church
# 45                             Ann's Chinese Restaurant
# 46                                        Pinch Chinese
# 47                              No. 1 Chinese Restauant
# 48                          Downtown Chinese Restaurant
# 49                                     Park Ave Chinese
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
